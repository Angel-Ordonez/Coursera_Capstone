# %%
import pandas as pd

url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

df_list = pd.read_html(url)

df = df_list [0]
df.head()
# Out:
#                                                    0                1  \
# 0                                    M1ANot assigned  M2ANot assigned
# 1                    M1BScarborough(Malvern / Rouge)  M2BNot assigned
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...  M2CNot assigned
# 3  M1EScarborough(Guildwood / Morningside / West ...  M2ENot assigned
# 4                             M1GScarborough(Woburn)  M2GNot assigned
#
#                                                 2  \
# 0                        M3ANorth York(Parkwoods)
# 1                   M3BNorth York(Don Mills)North
# 2  M3CNorth York(Don Mills)South(Flemingdon Park)
# 3                                 M3ENot assigned
# 4                                 M3GNot assigned
#
#                                                 3  \
# 0                 M4ANorth York(Victoria Village)
# 1  M4BEast York(Parkview Hill / Woodbine Gardens)
# 2                  M4CEast York(Woodbine Heights)
# 3                    M4EEast Toronto(The Beaches)
# 4                           M4GEast York(Leaside)
#
#                                                  4  \
# 0  M5ADowntown Toronto(Regent Park / Harbourfront)
# 1    M5BDowntown Toronto(Garden District, Ryerson)
# 2              M5CDowntown Toronto(St. James Town)
# 3                 M5EDowntown Toronto(Berczy Park)
# 4          M5GDowntown Toronto(Central Bay Street)
#
#                                                   5  \
# 0  M6ANorth York(Lawrence Manor / Lawrence Heights)
# 1                          M6BNorth York(Glencairn)
# 2                       M6CYork(Humewood-Cedarvale)
# 3                      M6EYork(Caledonia-Fairbanks)
# 4                     M6GDowntown Toronto(Christie)
#
#                                                 6                7  \
# 0  M7AQueen's Park(Ontario Provincial Government)  M8ANot assigned
# 1                                 M7BNot assigned  M8BNot assigned
# 2                                 M7CNot assigned  M8CNot assigned
# 3                                 M7ENot assigned  M8ENot assigned
# 4                                 M7GNot assigned  M8GNot assigned
#
#                                                    8
# 0                     M9AEtobicoke(Islington Avenue)
# 1  M9BEtobicoke(West Deane Park / Princess Garden...
# 2  M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 3                                    M9ENot assigned
# 4                                    M9GNot assigned

# %%
df.columns = [ 'PostalCode' , 'Borough' , 'Neighborhood' , 'Latitude' , 'Longitude' , 'Country' , 'State' , 'County' , 'City' ]
df.head()
# Out:
#                                           PostalCode          Borough  \
# 0                                    M1ANot assigned  M2ANot assigned
# 1                    M1BScarborough(Malvern / Rouge)  M2BNot assigned
# 2  M1CScarborough(Rouge Hill / Port Union / Highl...  M2CNot assigned
# 3  M1EScarborough(Guildwood / Morningside / West ...  M2ENot assigned
# 4                             M1GScarborough(Woburn)  M2GNot assigned
#
#                                      Neighborhood  \
# 0                        M3ANorth York(Parkwoods)
# 1                   M3BNorth York(Don Mills)North
# 2  M3CNorth York(Don Mills)South(Flemingdon Park)
# 3                                 M3ENot assigned
# 4                                 M3GNot assigned
#
#                                          Latitude  \
# 0                 M4ANorth York(Victoria Village)
# 1  M4BEast York(Parkview Hill / Woodbine Gardens)
# 2                  M4CEast York(Woodbine Heights)
# 3                    M4EEast Toronto(The Beaches)
# 4                           M4GEast York(Leaside)
#
#                                          Longitude  \
# 0  M5ADowntown Toronto(Regent Park / Harbourfront)
# 1    M5BDowntown Toronto(Garden District, Ryerson)
# 2              M5CDowntown Toronto(St. James Town)
# 3                 M5EDowntown Toronto(Berczy Park)
# 4          M5GDowntown Toronto(Central Bay Street)
#
#                                             Country  \
# 0  M6ANorth York(Lawrence Manor / Lawrence Heights)
# 1                          M6BNorth York(Glencairn)
# 2                       M6CYork(Humewood-Cedarvale)
# 3                      M6EYork(Caledonia-Fairbanks)
# 4                     M6GDowntown Toronto(Christie)
#
#                                             State           County  \
# 0  M7AQueen's Park(Ontario Provincial Government)  M8ANot assigned
# 1                                 M7BNot assigned  M8BNot assigned
# 2                                 M7CNot assigned  M8CNot assigned
# 3                                 M7ENot assigned  M8ENot assigned
# 4                                 M7GNot assigned  M8GNot assigned
#
#                                                 City
# 0                     M9AEtobicoke(Islington Avenue)
# 1  M9BEtobicoke(West Deane Park / Princess Garden...
# 2  M9CEtobicoke(Eringate / Bloordale Gardens / Ol...
# 3                                    M9ENot assigned
# 4                                    M9GNot assigned

# %%
code_list = df.values.tolist()

# %%
postal_code =[]
borough = []
nb = []
for i in code_list:
    for j in i:
        if j[3:] == 'Not assigned':
            pass
        else:
            postal_code.append(j[0:3])
            sep = j[3:].split('(')
            borough.append(sep[0])
            nb.append(sep[1].split(')')[0])
diccionario1 = {'Postal_Code':postal_code,'Borough':borough, 'Neighborhood':nb}

df1 = pd.DataFrame(diccionario1)
df1.head(10)
# Out:
#   Postal_Code           Borough                       Neighborhood
# 0         M3A        North York                          Parkwoods
# 1         M4A        North York                   Victoria Village
# 2         M5A  Downtown Toronto         Regent Park / Harbourfront
# 3         M6A        North York  Lawrence Manor / Lawrence Heights
# 4         M7A      Queen's Park      Ontario Provincial Government
# 5         M9A         Etobicoke                   Islington Avenue
# 6         M1B       Scarborough                    Malvern / Rouge
# 7         M3B        North York                          Don Mills
# 8         M4B         East York   Parkview Hill / Woodbine Gardens
# 9         M5B  Downtown Toronto           Garden District, Ryerson

# %%
df1.shape
# Out:
# (103, 3)

# %%
# !pip install geocoder
import geocoder
import opencage.geocoder
# Out:
# Requirement already satisfied: geocoder in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (1.38.1)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from geocoder) (1.16.0)
# Requirement already satisfied: click in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from geocoder) (8.0.4)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from geocoder) (2.28.1)
# Requirement already satisfied: ratelim in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: future in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from geocoder) (0.18.3)
# Requirement already satisfied: decorator in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from ratelim->geocoder) (5.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from requests->geocoder) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from requests->geocoder) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from requests->geocoder) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/Python-3.10/lib/python3.10/site-packages (from requests->geocoder) (1.26.11)

# %%
#Obtener los codigos postales para mandarselos a la api
PostalCodes = df1['Postal_Code'].tolist()
#PostalCodes

# %%
#Aqui se va a tardar por va a usar la api en for, y son como 40 iteraciones que hara

latitudes = []
longitudes = []
codigopostales = []

for codigo in PostalCodes:
    api_key = "b23627b996694bb8a398fc5e1ff7eff7"
    geocoder = opencage.geocoder.OpenCageGeocode(api_key)
    query = codigo
    result = geocoder.geocode(query)
    if len(result) > 0:
        latitudes.append(result[0]['geometry']['lat'])
        longitudes.append(result[0]['geometry']['lng'])
        #codigopostales.append(result[0]["components"]["postcode"])
        codigopostales.append(codigo)
    diccionario2 = {'Postal_Code': codigopostales, 'Latitude': latitudes, 'Longitude': longitudes }

# %%
#utilize la api de Geocoder y no el excel
df2 = pd.DataFrame(diccionario2)
df2.head(20)
# Out:
#    Postal_Code   Latitude   Longitude
# 0          M3A -12.198334  -76.962310
# 1          M4A  49.484291    8.466996
# 2          M5A  45.440588   28.018025
# 3          M6A  53.794164   -1.752006
# 4          M7A  25.254070   55.367819
# 5          M9A  49.326430 -122.452091
# 6          M1B  45.255294  -76.289731
# 7          M3B  45.439301   28.021317
# 8          M4B  45.440569   28.019181
# 9          M5B  45.440820   28.016137
# 10         M6B  44.427436   26.165441
# 11         M9B  43.650500  -79.551700
# 12         M1C  50.421545   14.921333
# 13         M3C  44.411376   26.168893
# 14         M4C  -6.173246   39.207869
# 15         M5C  43.651300  -79.375600
# 16         M6C  45.445082   -0.433347
# 17         M9C  43.643700  -79.576700
# 18         M1E  43.767800  -79.186600
# 19         M4E  43.678400  -79.294100

# %%
#DataFrame (Marco de datos) solicitado

df_completo = pd.merge(df1, df2, on='Postal_Code')
df_completo.head(20)
# Out:
#    Postal_Code           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A      Queen's Park
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
#
#                                          Neighborhood   Latitude   Longitude
# 0                                           Parkwoods -12.198334  -76.962310
# 1                                    Victoria Village  49.484291    8.466996
# 2                          Regent Park / Harbourfront  45.440588   28.018025
# 3                   Lawrence Manor / Lawrence Heights  53.794164   -1.752006
# 4                       Ontario Provincial Government  25.254070   55.367819
# 5                                    Islington Avenue  49.326430 -122.452091
# 6                                     Malvern / Rouge  45.255294  -76.289731
# 7                                           Don Mills  45.439301   28.021317
# 8                    Parkview Hill / Woodbine Gardens  45.440569   28.019181
# 9                            Garden District, Ryerson  45.440820   28.016137
# 10                                          Glencairn  44.427436   26.165441
# 11  West Deane Park / Princess Gardens / Martin Gr...  43.650500  -79.551700
# 12           Rouge Hill / Port Union / Highland Creek  50.421545   14.921333
# 13                                          Don Mills  44.411376   26.168893
# 14                                   Woodbine Heights  -6.173246   39.207869
# 15                                     St. James Town  43.651300  -79.375600
# 16                                 Humewood-Cedarvale  45.445082   -0.433347
# 17  Eringate / Bloordale Gardens / Old Burnhamthor...  43.643700  -79.576700
# 18                Guildwood / Morningside / West Hill  43.767800  -79.186600
# 19                                        The Beaches  43.678400  -79.294100
